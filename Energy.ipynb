# %%
import pandas as pd 
import seaborn as sn
import numpy as np
import matplotlib.pyplot as plt

# %%
energy=pd.read_csv('Downloads/electricityConsumptionAndProductioction.csv')

# %%
energy.head()
# Out:
#               DateTime  Consumption  Production  Nuclear  Wind  Hydroelectric  \
# 0  2019-01-01 00:00:00         6352        6527     1395    79           1383
# 1  2019-01-01 01:00:00         6116        5701     1393    96           1112
# 2  2019-01-01 02:00:00         5873        5676     1393   142           1030
# 3  2019-01-01 03:00:00         5682        5603     1397   191            972
# 4  2019-01-01 04:00:00         5557        5454     1393   159            960
#
#    Oil and Gas  Coal  Solar  Biomass
# 0         1896  1744      0       30
# 1         1429  1641      0       30
# 2         1465  1616      0       30
# 3         1455  1558      0       30
# 4         1454  1458      0       30

# %%
energy.tail()
# Out:
#                   DateTime  Consumption  Production  Nuclear  Wind  \
# 36767  2023-03-12 19:00:00         6500        6643     1407   111
# 36768  2023-03-12 20:00:00         6471        6484     1408    58
# 36769  2023-03-12 21:00:00         6194        6413     1406    39
# 36770  2023-03-12 22:00:00         5708        6217     1406     8
# 36771  2023-03-12 23:00:00         5409        5900     1403     0
#
#        Hydroelectric  Oil and Gas  Coal  Solar  Biomass
# 36767           3084          933  1047      0       60
# 36768           2983          933  1042      0       60
# 36769           2938          935  1031      0       62
# 36770           2823          917  1001      0       61
# 36771           2492          914  1030      0       60

# %%
energy.columns
# Out:
# Index(['DateTime', 'Consumption', 'Production', 'Nuclear', 'Wind',
#        'Hydroelectric', 'Oil and Gas', 'Coal', 'Solar', 'Biomass'],
#       dtype='object')

# %%
energy.shape
# Out:
# (36772, 10)

# %%
energy.describe
# Out:
# <bound method NDFrame.describe of                   DateTime  Consumption  Production  Nuclear  Wind  \
# 0      2019-01-01 00:00:00         6352        6527     1395    79
# 1      2019-01-01 01:00:00         6116        5701     1393    96
# 2      2019-01-01 02:00:00         5873        5676     1393   142
# 3      2019-01-01 03:00:00         5682        5603     1397   191
# 4      2019-01-01 04:00:00         5557        5454     1393   159
# ...                    ...          ...         ...      ...   ...
# 36767  2023-03-12 19:00:00         6500        6643     1407   111
# 36768  2023-03-12 20:00:00         6471        6484     1408    58
# 36769  2023-03-12 21:00:00         6194        6413     1406    39
# 36770  2023-03-12 22:00:00         5708        6217     1406     8
# 36771  2023-03-12 23:00:00         5409        5900     1403     0
#
#        Hydroelectric  Oil and Gas  Coal  Solar  Biomass
# 0               1383         1896  1744      0       30
# ...

# %%
print(energy.isnull().all())
# Out:
# DateTime         False
# Consumption      False
# Production       False
# Nuclear          False
# Wind             False
# Hydroelectric    False
# Oil and Gas      False
# Coal             False
# Solar            False
# Biomass          False
# dtype: bool

# %%
print(energy.isnull().sum().sum())
# Out:
# 0

# %%
energy["Nuclear"].mean()
# Out:
# 1293.468590231698

# %%
energy["Wind"].mean()
# Out:
# 785.7007233764821

# %%
energy["Hydroelectric"].mean()
# Out:
# 1801.6031491352117

# %%
energy["Oil and Gas"].mean()
# Out:
# 1181.6300174045468

# %%
energy["Coal"].mean()
# Out:
# 1270.0382356140542

# %%
energy["Solar"].mean()
# Out:
# 151.52409441966714

# %%
energy["Biomass"].mean()
# Out:
# 58.73082780376373

# %%
corrMatrix = energy.corr()
sn.heatmap(corrMatrix, annot = True)
plt.show()

# %%
energy.plot(kind='scatter', x='Production', y='Consumption')
plt.title('Overall Production with Consumption')
plt.xlabel('Production')
plt.ylabel('Consumption')
# Out:
# Text(0, 0.5, 'Consumption')

# %%
energy.plot(kind='scatter', x='Nuclear', y='Consumption')
plt.title('Nuclear with Consumption')
plt.xlabel('Nuclear')
plt.ylabel('Consumption')
# Out:
# Text(0, 0.5, 'Consumption')

# %%
energy.plot(kind='scatter', x='Wind', y='Consumption')
plt.title('Wind with Consumption')
plt.xlabel('Wind')
plt.ylabel('Consumption')
# Out:
# Text(0, 0.5, 'Consumption')

# %%
energy.plot(kind='scatter', x='Hydroelectric', y='Consumption')
plt.title('Hydroelectric with Consumption')
plt.xlabel('Hydroelectric')
plt.ylabel('Consumption')
# Out:
# Text(0, 0.5, 'Consumption')

# %%
energy.plot(kind='scatter', x='Oil and Gas', y='Consumption')
plt.title('Oil and Gas with Consumption')
plt.xlabel('Oil and Gas')
plt.ylabel('Consumption')
# Out:
# Text(0, 0.5, 'Consumption')

# %%
energy.plot(kind='scatter', x='Coal', y='Consumption')
plt.title('Coal with Consumption')
plt.xlabel('Coal')
plt.ylabel('Consumption')
# Out:
# Text(0, 0.5, 'Consumption')

# %%
energy.plot(kind='scatter', x='Solar', y='Consumption')
plt.title('Solar with Consumption')
plt.xlabel('Solar')
plt.ylabel('Consumption')
# Out:
# Text(0, 0.5, 'Consumption')

# %%
energy.plot(kind='scatter', x='Biomass', y='Consumption')
plt.title('Biomass with Consumption')
plt.xlabel('Biomass')
plt.ylabel('Consumption')
# Out:
# Text(0, 0.5, 'Consumption')

# %%
sn.pairplot(energy)
